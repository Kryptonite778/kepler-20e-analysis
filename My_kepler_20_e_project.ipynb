# %% [markdown]
# <a href="https://colab.research.google.com/github/Kryptonite778/kepler-20e-analysis/blob/main/My_kepler_20_e_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Md. Aiman Sheikh
# ## Planet 2: (Kepler-20 e)

# %% [markdown]
# ##*Introduction*
# Kepler-20 e is a terrestrial exoplanet that orbits a (G-type star) Sun.
# It is notable for being one of the first Earth-sized exoplanets found orbiting a Sun-like star.
# Studying such planets helps us understand planetary systems beyond our solar system,
# their orbital properties, and potential similarities to Earth.

# %% [markdown]
# ##***1. Recovering Kepler-20 e in Kepler data***

# %% [markdown]
# ###1.1 Target Pixel File (TPF) Image
# *Figure 1:*
# *  An image of the pixels around Kepler-20 e from the Kepler spacecraft.
#
# * Shows which pixels were used to collect the star’s light (the aperture). Important to check if nearby stars or noise could contaminate your measurements.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###1.2 Raw Light Curve
# *Figure 2:*
# * Raw light curve of Kepler‑20 e over the observed quarter.
# * Displays the original data — we can see instrument trends, noise, and the first hints of transits (tiny dips).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##***2. Kepler available lightcurves for (Kepler-20 e)***

# %% [markdown]
# ### 2.1 Flattened Light Curve
#
# *Figure 3:*
#
# * This is the data used for detection; makes transits obvious and noise measurable.
# *  Flattened light curve after trend removal — used for transit search (BLS).
# *  Makes the periodic dips (transits) much clearer, preparing the data for transit searches.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###2.2 BLS Periodogram
#
# *Figure 4:*
# * Demonstrates the detected periodicity and justifies the chosen period for folding.
# * BLS periodogram showing highest peak at P = [best_period] days

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###2.3 Phase-folded transit
# *Figure 5:*
# * All the transits stacked together on one plot by folding the data at the detected period, with a transit model overlaid.
# * Confirms the detection — shows the average transit shape, depth (how much light is blocked), and duration (how long the planet takes to cross).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###2.4 Model residuals
# *Figure 6:*
#
# * The difference between the observed light curve and the fitted transit model.
# * Checks how well the model explains the data. If the residuals look random (just noise), the fit is good. If patterns remain, the model may be missing something (e.g., additional planets, star spots).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##*3. Visualizing periodic signals using a River Plot*

# %% [markdown]
# ###3.1 River Plot
# *Figure 7:*
# * Each transit shown as a stripe, stacked vertically by orbital cycle (like a waterfall).
# * We can observe if the timing of transits drifts over time (Transit Timing Variations, TTVs). A straight vertical band = consistent orbit; a wavy band = timing variations or errors.

# %% [markdown]
# ![plotting river.PNG](data:image/png;base64,...)

# %% [markdown]
# ##*4. Periodogram from Kepler Data*

# %% [markdown]
# ### 4.1Stellar periodogram (rotation/asteroseismology)
# *Figure 8:*
# * Power spectrum of the light curve in frequency space.
# * Used to measure the star’s rotation (spots creating periodic brightness changes) or even stellar oscillations (asteroseismology). Tells us about the star, not the planet.

# %% [markdown]
# ![plots.PNG](data:image/png;base64,...)

# %% [markdown]
# ## *5. Comparative Analysis: Kepler-20e vs Earth*
#
# - **Kepler-20e**
#   - Orbital distance: ~0.05 AU (very close to its star)
#   - Orbital period: ~6 days
#   - Radius: ~0.87 × Earth
#   - Temperature: Too hot for habitability
#
# - **Earth**
#   - Orbital distance: 1 AU
#   - Orbital period: 365 days
#   - Radius: 1 Earth radius
#   - Temperature: Habitable zone
#
# **Observation:** Kepler-20e, though Earth-sized, orbits much closer to its star, making it too hot to sustain life as we know it.
#
#
# ![Earth and Kepler-20 e.PNG](data:image/png;base64,...)
